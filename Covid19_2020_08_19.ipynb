# %%
import pandas as pd

# %%
df = pd.read_csv('daily - 2020-08-19.csv')

# %%
df
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 0    20200819      56   5502927  63441940   4374.0                43313.0
# 1    20200818      56   5457824  62806109   4412.0                43747.0
# 2    20200817      56   5417366  62203753   4298.0                43485.0
# 3    20200816      56   5379549  61593454   4302.0                44028.0
# 4    20200815      56   5336466  60857656   4452.0                44794.0
# ..        ...     ...       ...       ...      ...                    ...
# 206  20200126       1         2         0      NaN                    NaN
# 207  20200125       1         2         0      NaN                    NaN
# 208  20200124       1         2         0      NaN                    NaN
# 209  20200123       1         2         0      NaN                    NaN
# 210  20200122       1         2         0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
df.shape
# Out:
# (211, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      211 non-null    int64
#  1   states                    211 non-null    int64
#  2   positive                  211 non-null    int64
#  3   negative                  211 non-null    int64
#  4   pending                   169 non-null    float64
#  5   hospitalizedCurrently     156 non-null    float64
#  6   hospitalizedCumulative    169 non-null    float64
#  7   inIcuCurrently            147 non-null    float64
#  8   inIcuCumulative           148 non-null    float64
#  9   onVentilatorCurrently     148 non-null    float64
#  10  onVentilatorCumulative    141 non-null    float64
#  11  recovered                 148 non-null    float64
#  12  dateChecked               211 non-null    object
# ...

# %%
pd.set_option('display.max_columns', 25)

# %%
df.head(50)
# Out:
#         date  states  positive  negative  pending  hospitalizedCurrently  \
# 0   20200819      56   5502927  63441940   4374.0                43313.0
# 1   20200818      56   5457824  62806109   4412.0                43747.0
# 2   20200817      56   5417366  62203753   4298.0                43485.0
# 3   20200816      56   5379549  61593454   4302.0                44028.0
# 4   20200815      56   5336466  60857656   4452.0                44794.0
# 5   20200814      56   5279863  60172837   4415.0                45776.0
# 6   20200813      56   5224214  59387820   4239.0                47228.0
# 7   20200812      56   5172509  58558796   4174.0                47968.0
# 8   20200811      56   5116474  58135783   4118.0                48498.0
# 9   20200810      56   5060880  57452294   3966.0                48635.0
# 10  20200809      56   4999139  56777043   3871.0                48902.0
# 11  20200808      56   4947848  56114899   3888.0                49884.0
# ...

# %%
df.tail(60)
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 151  20200321      56     32910    177262   3468.0                 1436.0
# 152  20200320      56     26025    138814   3330.0                 1042.0
# 153  20200319      56     19770    108407   3016.0                  617.0
# 154  20200318      56     15099     84997   2526.0                  416.0
# 155  20200317      56     11928     63104   1687.0                  325.0
# 156  20200316      56      8315     49397   1691.0                    NaN
# 157  20200315      51      6746     33042   2242.0                    NaN
# 158  20200314      51      5495     26689   1236.0                    NaN
# 159  20200313      51      4580     22994   1130.0                    NaN
# 160  20200312      51      3555     14848    673.0                    NaN
# 161  20200311      50      2873     10220    563.0                    NaN
# 162  20200310      50      2346      6929    469.0                    NaN
# ...

# %%
df.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'lastModified',
#        'total', 'totalTestResults', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %%
df['positive'].value_counts()
# Out:
# 2          7
# 3          3
# 8          2
# 13         2
# 18         2
#           ..
# 199786     1
# 3291969    1
# 7          1
# 1684632    1
# 1538       1
# Name: positive, Length: 200, dtype: int64

# %%
df.loc[1]
# Out:
# date                                                        20200818
# states                                                            56
# positive                                                     5457824
# negative                                                    62806109
# pending                                                         4412
# hospitalizedCurrently                                          43747
# hospitalizedCumulative                                        351234
# inIcuCurrently                                                  8927
# inIcuCumulative                                                16123
# onVentilatorCurrently                                           2468
# onVentilatorCumulative                                          1695
# recovered                                                1.88917e+06
# dateChecked                                     2020-08-18T00:00:00Z
# death                                                         163595
# ...

# %%
df.loc[0:50]
# Out:
#         date  states  positive  negative  pending  hospitalizedCurrently  \
# 0   20200819      56   5502927  63441940   4374.0                43313.0
# 1   20200818      56   5457824  62806109   4412.0                43747.0
# 2   20200817      56   5417366  62203753   4298.0                43485.0
# 3   20200816      56   5379549  61593454   4302.0                44028.0
# 4   20200815      56   5336466  60857656   4452.0                44794.0
# 5   20200814      56   5279863  60172837   4415.0                45776.0
# 6   20200813      56   5224214  59387820   4239.0                47228.0
# 7   20200812      56   5172509  58558796   4174.0                47968.0
# 8   20200811      56   5116474  58135783   4118.0                48498.0
# 9   20200810      56   5060880  57452294   3966.0                48635.0
# 10  20200809      56   4999139  56777043   3871.0                48902.0
# 11  20200808      56   4947848  56114899   3888.0                49884.0
# ...

# %%
df.loc[0:50,'positiveIncrease']
# Out:
# 0     45103
# 1     40458
# 2     37817
# 3     43083
# 4     56603
# 5     55649
# 6     51705
# 7     56035
# 8     55594
# 9     61741
# 10    51291
# 11    34185
# 12    61520
# 13    54184
# 14    52265
# 15    51568
# 16    49561
# 17    48266
# 18    60692
# 19    67755
# 20    69466
# 21    66969
# 22    56229
# 23    55134
# 24    61713
# 25    65075
# 26    75204
# 27    71354
# 28    69150
# 29    63642
# 30    56971
# 31    64884
# 32    65180
# 33    77233
# 34    70953
# 35    65382
# 36    62879
# 37    58465
# 38    60978
# 39    63007
# 40    66645
# 41    58836
# 42    62147
# 43    51766
# 44    41600
# 45    45789
# 46    54734
# 47    54223
# 48    53826
# 49    50674
# 50    47462
# Name: positiveIncrease, dtype: int64

# %%
df.loc[0:50,['date','positiveIncrease']]
# Out:
#         date  positiveIncrease
# 0   20200819             45103
# 1   20200818             40458
# 2   20200817             37817
# 3   20200816             43083
# 4   20200815             56603
# 5   20200814             55649
# 6   20200813             51705
# 7   20200812             56035
# 8   20200811             55594
# 9   20200810             61741
# 10  20200809             51291
# 11  20200808             34185
# 12  20200807             61520
# 13  20200806             54184
# 14  20200805             52265
# 15  20200804             51568
# 16  20200803             49561
# 17  20200802             48266
# 18  20200801             60692
# 19  20200731             67755
# 20  20200730             69466
# 21  20200729             66969
# 22  20200728             56229
# 23  20200727             55134
# 24  20200726             61713
# 25  20200725             65075
# 26  20200724             75204
# 27  20200723             71354
# 28  20200722             69150
# ...

# %%
df.loc[0:160,['date','positiveIncrease']]
# Out:
#          date  positiveIncrease
# 0    20200819             45103
# 1    20200818             40458
# 2    20200817             37817
# 3    20200816             43083
# 4    20200815             56603
# ..        ...               ...
# 156  20200316              1569
# 157  20200315              1251
# 158  20200314               915
# 159  20200313              1025
# 160  20200312               682
#
# [161 rows x 2 columns]

# %%
df_date = df.set_index('date')

# %%
new_df = df.loc[210:0:-1]

# %%
new_df
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 210  20200122       1         2         0      NaN                    NaN
# 209  20200123       1         2         0      NaN                    NaN
# 208  20200124       1         2         0      NaN                    NaN
# 207  20200125       1         2         0      NaN                    NaN
# 206  20200126       1         2         0      NaN                    NaN
# ..        ...     ...       ...       ...      ...                    ...
# 4    20200815      56   5336466  60857656   4452.0                44794.0
# 3    20200816      56   5379549  61593454   4302.0                44028.0
# 2    20200817      56   5417366  62203753   4298.0                43485.0
# 1    20200818      56   5457824  62806109   4412.0                43747.0
# 0    20200819      56   5502927  63441940   4374.0                43313.0
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
df_date.loc[20200818,'positive']
# Out:
# 5457824

# %%
df_date.sort_index()
# Out:
#           states  positive  negative  pending  hospitalizedCurrently  \
# date
# 20200122       1         2         0      NaN                    NaN
# 20200123       1         2         0      NaN                    NaN
# 20200124       1         2         0      NaN                    NaN
# 20200125       1         2         0      NaN                    NaN
# 20200126       1         2         0      NaN                    NaN
# ...          ...       ...       ...      ...                    ...
# 20200815      56   5336466  60857656   4452.0                44794.0
# 20200816      56   5379549  61593454   4302.0                44028.0
# 20200817      56   5417366  62203753   4298.0                43485.0
# 20200818      56   5457824  62806109   4412.0                43747.0
# 20200819      56   5502927  63441940   4374.0                43313.0
#
#           hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# ...

# %%
df_date.loc[20200312:20200819:-1]
# Out:
#           states  positive  negative  pending  hospitalizedCurrently  \
# date
# 20200312      51      3555     14848    673.0                    NaN
# 20200313      51      4580     22994   1130.0                    NaN
# 20200314      51      5495     26689   1236.0                    NaN
# 20200315      51      6746     33042   2242.0                    NaN
# 20200316      56      8315     49397   1691.0                    NaN
# ...          ...       ...       ...      ...                    ...
# 20200815      56   5336466  60857656   4452.0                44794.0
# 20200816      56   5379549  61593454   4302.0                44028.0
# 20200817      56   5417366  62203753   4298.0                43485.0
# 20200818      56   5457824  62806109   4412.0                43747.0
# 20200819      56   5502927  63441940   4374.0                43313.0
#
#           hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# ...

# %%
df_date2
# Out:
#           states  positive  negative  pending  hospitalizedCurrently  \
# date
# 20200312      51      3555     14848    673.0                    NaN
# 20200313      51      4580     22994   1130.0                    NaN
# 20200314      51      5495     26689   1236.0                    NaN
# 20200315      51      6746     33042   2242.0                    NaN
# 20200316      56      8315     49397   1691.0                    NaN
# ...          ...       ...       ...      ...                    ...
# 20200815      56   5336466  60857656   4452.0                44794.0
# 20200816      56   5379549  61593454   4302.0                44028.0
# 20200817      56   5417366  62203753   4298.0                43485.0
# 20200818      56   5457824  62806109   4412.0                43747.0
# 20200819      56   5502927  63441940   4374.0                43313.0
#
#           hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# ...

# %%
filt0 = (df_date2['hospitalizedCurrently'] > 100)

# %%
filt0
# Out:
# date
# 20200819     True
# 20200818     True
# 20200817     True
# 20200816     True
# 20200815     True
#             ...
# 20200126    False
# 20200125    False
# 20200124    False
# 20200123    False
# 20200122    False
# Length: 211, dtype: bool

# %%
my_temp_df = df_date2.loc[filt0,['hospitalizedCurrently','positiveIncrease']]

# %%
from matplotlib import pyplot as plt

# %%
df_date.plot()

# %%
new_df.plot(y='positiveIncrease')
